# %%
import utils.preprocessing as pp
import pandas as pd

# %% [markdown]
# ### 1. Save final data frame locally as csv

# %% [markdown]
# Takes ~30 seconds

# %%
df = pp.load_final_raw_df()
df.to_csv('../data/large/final_df_v1.csv', index=False)

# %% [markdown]
# Takes ~2 seconds

# %%
df_loaded = pd.read_csv('../data/large/final_df_v1.csv')
